# %% [markdown]
# # Imports

# %%
# %pip install -q hf_transfer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 10.5 MB/s eta 0:00:00a 0:00:01
# Note: you may need to restart the kernel to use updated packages.

# %%
import wandb
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login
import os

# %% [markdown]
# # Clone Repo

# %%
user_secrets = UserSecretsClient()

github_token = user_secrets.get_secret("GITHUB_VIETTEL")

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
os.environ["GITHUB_TOKEN"] = github_token
# !git clone https://oauth2:$GITHUB_TOKEN@github.com/KangaOnGit/LLM-Alignment-Pipeline.git
# Out:
# Cloning into 'LLM-Alignment-Pipeline'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 232 (delta 93), reused 187 (delta 59), pack-reused 0 (from 0)
# Receiving objects: 100% (232/232), 65.11 KiB | 1.48 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
cd LLM-Alignment-Pipeline
# Out:
# /kaggle/working/LLM-Alignment-Pipeline

# %% [markdown]
# # Login

# %%
wandb.login(key=user_secrets.get_secret("WANDB"))

# %% [markdown]
# ## Install Requirements

# %%
pip install -U unsloth trl peft accelerate bitsandbytes

# %%
pip install pydantic fastapi datasets jinja2 pyyaml wandb huggingface_hub

# %% [markdown]
# ## Dependency Hell

# %%
# !pip uninstall -y tensorflow tensorflow-cpu tf-keras

# %%
# !python -m scripts.train_grpo
